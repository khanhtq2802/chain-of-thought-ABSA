# %% [markdown]
# # xây dựng tập huấn luyện

# %%
import ast
import random
from torch.utils.data import DataLoader
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, AdamW

# %%
def process_train_data(file_path):
    # Đọc dữ liệu từ file
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    # Tạo các tác vụ
    task_data = {}
    for i in range(len(lines)):
        text_sentence, aspect_category_sentiment_opinions_str = lines[i].strip().split("####")
        aspect_category_sentiment_opinions = ast.literal_eval(aspect_category_sentiment_opinions_str)
        # Tạo các chuỗi cần thiết
        aspects_str = "; ".join(sorted(set([aspect for aspect, _, _, _ in aspect_category_sentiment_opinions])))
        opinions_str = "; ".join(sorted(set([opinion for _, _, _, opinion in aspect_category_sentiment_opinions])))
        aspect_opinions_str = "; ".join(sorted(set([f"{aspect}, {opinion}" for aspect, _, _, opinion in aspect_category_sentiment_opinions])))
        aspect_opinions_sentiment_categories_str = "; ".join(sorted([f"{aspect}, {opinion}, {sentiment}, {category}" for aspect, category, sentiment, opinion in aspect_category_sentiment_opinions]))

        # Tác vụ 1: I -> A
        task_data[f"{i}_1"] = {
            "id": i,
            "task": 1,
            "text_label": aspects_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 2: I -> O
        task_data[f"{i}_2"] = {
            "id": i,
            "task": 2,
            "text_label": opinions_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 3: I, A -> A-O
        task_data[f"{i}_3"] = {
            "id": i,
            "task": 3,
            "text_label": aspect_opinions_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 4: I, O -> A-O
        task_data[f"{i}_4"] = {
            "id": i,
            "task": 4,
            "text_label": aspect_opinions_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 5: I, A, O -> A-O
        task_data[f"{i}_5"] = {
            "id": i,
            "task": 5,
            "text_label": aspect_opinions_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 6: I, A-O, A-O, A-O -> A-O
        task_data[f"{i}_6"] = {
            "id": i,
            "task": 6,
            "text_label": aspect_opinions_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
        # Tác vụ 7: I, A-O -> A-C-S-O
        task_data[f"{i}_7"] = {
            "id": i,
            "task": 7,
            "text_label": aspect_opinions_sentiment_categories_str,
            "text_predict": "",
            "text_sentence": text_sentence,
        }
    return task_data

# %%
# Đường dẫn đến file
# train_data = process_train_data("/chain-of-thought-ABSA/data/acos/rest16/train.txt")
# train_data

# %%
def collate_fn(batch_keys, train_data, tokenizer):
    text_inputs, text_labels = [], []
    for key in batch_keys:
        item_data = train_data[key]

        id = item_data["id"]
        task = item_data['task']
        text_sentence = item_data["text_sentence"]

        # Task 1
        if task == 1:
            text_input = f"Task 1, predict aspects\nInput: {text_sentence}"
        # Task 2
        if task == 2:
            text_input = f"Task 2, predict opinions\nInput: {text_sentence}"
        # Task 3: Sử dụng predict từ task1
        if task == 3:
            task_1_output = train_data[f"{id}_1"]["text_predict"]
            text_input = f"Task 3, predict aspect-opinion sets with these aspects\nInput: {text_sentence}\nAspects: {task_1_output}"
        # Task 4: Sử dụng predict từ task2
        if task == 4:
            task_2_output = train_data[f"{id}_2"]["text_predict"]
            text_input = f"Task 4, predict aspect-opinion sets with these opinions\nInput: {text_sentence}\nOpinions: {task_2_output}"
        # Task 5: Sử dụng predict từ task1 và task2
        if task == 5:
            task_1_output = train_data[f"{id}_1"]["text_predict"]
            task_2_output = train_data[f"{id}_2"]["text_predict"]
            text_input = f"Task 5, predict aspect-opinion sets with these aspects and opinions\nInput: {text_sentence}\nAspects: {task_1_output}\nOpinions: {task_2_output}"
        # Task 6: Sử dụng predict từ task3, task4, task5
        if task == 6:
            task_3_output = train_data[f"{id}_3"]["text_predict"]
            task_4_output = train_data[f"{id}_4"]["text_predict"]
            task_5_output = train_data[f"{id}_5"]["text_predict"]
            text_input = f"Task 6, predict aspect-opinion sets with results of task 3, 4, 5\nInput: {text_sentence}\nTask 3 results: {task_3_output}\nTask 4 results: {task_4_output}\nTask 5 results: {task_5_output}"
        # Task 7: Sử dụng predict từ task6
        if task == 7:
            task_6_output = train_data[f"{id}_6"]["text_predict"]
            text_input = f"Task 7, predict aspect-opinion-sentiment-category sets with these aspect-opinion sets\nInput: {text_sentence}\nAspect-opinion sets: {task_6_output}"
        
        # Tokenize inputs and labels
        text_inputs.append(text_input)
        text_labels.append(item_data["text_label"])
    
    # Tokenize the entire batch
    tokenized_inputs = tokenizer(text_inputs, padding=True, return_tensors="pt")
    tokenized_labels = tokenizer(text_labels, padding=True, return_tensors="pt")
    tokenized_labels["input_ids"][tokenized_labels["input_ids"] == tokenizer.pad_token_id] = -100
    # Return the batch as a dictionary
    return {
        "batch_keys": batch_keys,
        "input_ids": tokenized_inputs["input_ids"],
        "attention_mask": tokenized_inputs["attention_mask"],
        "labels": tokenized_labels["input_ids"],
    }

def build_dataloader(train_data, batch_size, tokenizer):
    return DataLoader(
        list(train_data.keys()),
        batch_size=batch_size,
        shuffle=True,  # Shuffle để tăng tính ngẫu nhiên
        collate_fn=lambda batch_keys: collate_fn(batch_keys, train_data, tokenizer)
    )

# %%
# tokenizer = T5Tokenizer.from_pretrained("t5-base")
# dataloader = build_dataloader(train_data, 2, tokenizer)
# for batch in dataloader:
#     # print(batch)
#     print(tokenizer.decode(batch['input_ids'][0]))
#     break

# %%
# dataloader = build_dataloader(train_data, 0.5, 1, T5Tokenizer.from_pretrained("t5-base"))
# max_len_input_ids = 0
# max_len_labels = 0
# for batch in dataloader:
#     if max_len_input_ids < len(batch['input_ids'][0]):
#         max_len_input_ids = len(batch['input_ids'][0])
    
#     if max_len_labels < len(batch['labels'][0]):
#         max_len_labels = len(batch['labels'][0])
# print(max_len_input_ids, max_len_labels)

# %% [markdown]
# # xử lý tập validation và đánh giá mô hình

# %%
# === HÀM XỬ LÝ VALIDATION DATA ===
def process_validation_data(validation_file):
    # Đọc dữ liệu từ file
    with open(validation_file, "r", encoding="utf-8") as f:
        lines = f.readlines()
    data = []
    for line in lines:
        text_sentence, aspect_category_sentiment_opinions_str = line.strip().split("####")
        data.append({
            "text_sentence": text_sentence, 
            "aspect_category_sentiment_opinions": ast.literal_eval(aspect_category_sentiment_opinions_str)
        })
    return data

# === HÀM ĐỂ CHẠY SUY LUẬN TRÊN BATCH ===
def batch_predict(model, tokenizer, inputs, device):
    encoded_inputs = tokenizer(inputs, return_tensors="pt", padding=True).to(device)
    outputs = model.generate(**encoded_inputs, max_length=124)
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)

def evaluate_pipeline_batch(model, tokenizer, validation_data, device, batch_size):
    # Initialize counters
    count_true_positive = 0
    count_false_positive = 0
    count_false_negative = 0
    
    # Divide validation data into batches
    for i in range(0, len(validation_data), batch_size):
        batch = validation_data[i:i + batch_size]
        text_sentences = [sample["text_sentence"] for sample in batch]
        text_labels = [sample["aspect_category_sentiment_opinions"] for sample in batch]

        # Step 1: Task 1 (I -> A)
        task_1_inputs = [
            f"Task 1, predict aspects\nInput: {text_sentence}"
            for text_sentence in text_sentences]
        task_1_outputs = batch_predict(model, tokenizer, task_1_inputs, device)

        # Step 2: Task 2 (I -> O)
        task_2_inputs = [
            f"Task 2, predict opinions\nInput: {text_sentence}" 
            for text_sentence in text_sentences]
        task_2_outputs = batch_predict(model, tokenizer, task_2_inputs, device)

        # Step 3: Task 3 (I, A -> A-O)
        task_3_inputs = [
            f"Task 3, predict aspect-opinion sets with these aspects\nInput: {text_sentence}\nAspects: {task_1_output}"
            for text_sentence, task_1_output in zip(text_sentences, task_1_outputs)
        ]
        task_3_outputs = batch_predict(model, tokenizer, task_3_inputs, device)

        # Step 4: Task 4 (I, O -> A-O)
        task_4_inputs = [
            f"Task 4, predict aspect-opinion sets with these opinions\nInput: {text_sentence}\nOpinions: {task_2_output}"
            for text_sentence, task_2_output in zip(text_sentences, task_2_outputs)
        ]
        task_4_outputs = batch_predict(model, tokenizer, task_4_inputs, device)

        # Step 5: Task 5 (I, A, O -> A-O)
        task_5_inputs = [
            f"Task 5, predict aspect-opinion sets with these aspects and opinions\nInput: {text_sentence}\nAspects: {task_1_output}\nOpinions: {task_2_output}"
            for text_sentence, task_1_output, task_2_output in zip(text_sentences, task_1_outputs, task_2_outputs)
        ]
        task_5_outputs = batch_predict(model, tokenizer, task_5_inputs, device)

        # Step 6: Task 6 (I, A-O -> A-O)
        task_6_inputs = [
            f"Task 6, predict aspect-opinion sets with results of task 3, 4, 5\nInput: {text_sentence}\nTask 3 results: {task_3_output}\nTask 4 results: {task_4_output}\nTask 5 results: {task_5_output}"
            for text_sentence, task_3_output, task_4_output, task_5_output in zip(text_sentences, task_3_outputs, task_4_outputs, task_5_outputs)
        ]
        task_6_outputs = batch_predict(model, tokenizer, task_6_inputs, device)

        # Step 7: Task 7 (I, A-O -> A-O-S)
        task_7_inputs = [
            f"Task 7, predict aspect-opinion-sentiment-category sets with these aspect-opinion sets\nInput: {text_sentence}\nAspect-opinion sets: {task_6_output}"
            for text_sentence, task_6_output in zip(text_sentences, task_6_outputs)
        ]
        task_7_outputs = batch_predict(model, tokenizer, task_7_inputs, device)

        # Evaluate predictions
        for task_7_output, text_label in zip(task_7_outputs, text_labels):
            predicted_set = set(task_7_output.split('; '))  # Split predictions into sets of tuples
            true_set = set(f"{aspect}, {opinion}, {sentiment}, {category}" for aspect, category, sentiment, opinion in text_label) # Split ground truth into sets of tuples
            print('predicted_set =', predicted_set)
            print('true_set =', true_set)
            # Calculate true positives, false positives, and false negatives
            count_true_positive += len(predicted_set & true_set)
            count_false_positive += len(predicted_set - true_set)
            count_false_negative += len(true_set - predicted_set)
    
    # Compute Precision, Recall, and F1-score
    precision = count_true_positive / (count_true_positive + count_false_positive) if count_true_positive + count_false_positive > 0 else 0
    recall = count_true_positive / (count_true_positive + count_false_negative) if count_true_positive + count_false_negative > 0 else 0
    f1 = (2 * precision * recall) / (precision + recall) if precision + recall > 0 else 0
    
    return precision, recall, f1

# %% [markdown]
# # Đánh giá trên tập test

# %%
validation_data = process_validation_data("/chain-of-thought-ABSA/data/acos/laptop16/test.txt")

model = T5ForConditionalGeneration.from_pretrained("t5-base")
model.load_state_dict(torch.load("/chain-of-thought-ABSA/results/experiment_7/13.pt"))
model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
evaluate_pipeline_batch(
    model=model, 
    tokenizer = T5Tokenizer.from_pretrained("t5-base"), 
    validation_data = validation_data, 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu"), 
    batch_size = 16)
# Out:
# /tmp/ipykernel_118868/2312903394.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/chain-of-thought-ABSA/results/experiment_7/13.pt"))
# predicted_set = {'unit, not worth, negative, laptop price'}
# true_set = {'unit, not worth, negative, laptop price'}
# predicted_set = {'NULL, difficult, negative, laptop design_features'}
# true_set = {'acer 11, small, negative, laptop design_features', 'acer 11, difficult, negative, laptop design_features'}
# predicted_set = {'emmc, NULL, neutral, hard_disc general'}
# true_set = {'ssd drive, NULL, negative, hard_disc operation_performance'}
# predicted_set = {'computer, difficulty, negative, laptop usability'}
# true_set = {'computer, difficulty, negative, laptop usability'}
# predicted_set = {'chrome os, NULL, neutral, os general'}
# true_set = {'chrome os, NULL, neutral, os general'}
# predicted_set = {'chromebook, NULL, negative, laptop operation_performance'}
# true_set = {'chrome, NULL, negative, os operation_performance'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, suck, negative, laptop general', 'NULL, badly, negative, laptop general'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop general'}
# predicted_set = {'keyboard, NULL, negative, keyboard general'}
# true_set = {'keyboard, rarely, negative, keyboard general'}
# predicted_set = {'touchscreen chromebook, great, positive, laptop price'}
# true_set = {'touchscreen chromebook, great, positive, laptop price'}
# predicted_set = {'NULL, glitchy, negative, laptop operation_performance', 'NULL, barely usable, negative, laptop operation_performance'}
# true_set = {'NULL, barely usable, negative, hardware operation_performance', 'NULL, glitchy, negative, hardware operation_performance'}
# predicted_set = {'touch pad, failed, negative, hardware operation_performance'}
# true_set = {'touch pad, failed, negative, hardware operation_performance'}
# predicted_set = {'NULL, unproductive, negative, keyboard operation_performance'}
# true_set = {'keys, unproductive, negative, keyboard general'}
# predicted_set = {'device, NULL, negative, laptop operation_performance'}
# true_set = {'device, worse, negative, laptop general'}
# predicted_set = {'trackpad, NULL, negative, keyboard operation_performance'}
# true_set = {'track pad, NULL, negative, keyboard usability'}
# predicted_set = {'os, NULL, negative, os operation_performance'}
# true_set = {'os, NULL, neutral, os general'}
# predicted_set = {"hdmi out, ' t work right, negative, ports operation_performance"}
# true_set = {'hdmi, NULL, negative, ports quality'}
# predicted_set = {'NULL, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, neutral, support general'}
# predicted_set = {'touchscreen, NULL, negative, display operation_performance'}
# true_set = {'touchscreen, NULL, negative, hardware operation_performance'}
# predicted_set = {'acer, NULL, negative, support quality'}
# true_set = {'acer, defect, negative, company general'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop general'}
# predicted_set = {'sound quality, decent, positive, multimedia_devices quality'}
# true_set = {'sound, decent, positive, multimedia_devices quality'}
# predicted_set = {'power adapter, flimsy, negative, power_supply design_features'}
# true_set = {'power adapter, flimsy, negative, power_supply general'}
# predicted_set = {'wi - fi, NULL, negative, ports operation_performance'}
# true_set = {'wi - fi, NULL, negative, ports quality'}
# predicted_set = {'NULL, regret, negative, laptop general'}
# true_set = {'NULL, regret, negative, laptop general'}
# predicted_set = {'NULL, NULL, negative, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, laptop quality'}
# predicted_set = {'customer support, horrible, negative, support general', 'product, great, positive, laptop general'}
# true_set = {'customer support, horrible, negative, support general', 'product, great, positive, laptop general'}
# predicted_set = {'support, NULL, negative, support general'}
# true_set = {'support, NULL, negative, support general'}
# predicted_set = {'NULL, terrible, negative, laptop operation_performance'}
# true_set = {'NULL, terrible, negative, laptop operation_performance'}
# predicted_set = {'NULL, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop general'}
# predicted_set = {'screen, great, positive, display general'}
# true_set = {'screen, great, positive, display general'}
# predicted_set = {'charging adapter, NULL, negative, power_supply operation_performance'}
# true_set = {'charging adapter, NULL, negative, power_supply operation_performance'}
# predicted_set = {'computer, NULL, negative, laptop operation_performance'}
# true_set = {'computer, NULL, negative, laptop operation_performance'}
# predicted_set = {'NULL, well, positive, laptop operation_performance', 'NULL, hiccup, negative, laptop operation_performance'}
# true_set = {'NULL, well, positive, laptop operation_performance'}
# predicted_set = {'screen, NULL, negative, display operation_performance'}
# true_set = {'screen, NULL, negative, display operation_performance'}
# predicted_set = {'battery, NULL, negative, battery operation_performance'}
# true_set = {'battery, NULL, negative, battery operation_performance'}
# predicted_set = {'fan, annoying, negative, fans&cooling operation_performance', 'fan, good, positive, fans&cooling operation_performance'}
# true_set = {'sound, annoying, negative, fans&cooling operation_performance', 'fan, annoying, negative, fans&cooling operation_performance'}
# predicted_set = {'nano edge display, nice, positive, display general'}
# true_set = {'nano edge display, nice, positive, display operation_performance'}
# predicted_set = {'NULL, fine, positive, laptop general'}
# true_set = {'NULL, fine, positive, laptop general'}
# predicted_set = {'audio, NULL, negative, multimedia_devices operation_performance'}
# true_set = {'audio, NULL, negative, multimedia_devices operation_performance'}
# predicted_set = {'NULL, slow, negative, laptop operation_performance'}
# true_set = {'NULL, slow, negative, laptop operation_performance'}
# predicted_set = {'NULL, terrible, negative, laptop operation_performance'}
# true_set = {'NULL, terrible, negative, laptop operation_performance'}
# predicted_set = {'backlit keyboard, pain, negative, keyboard operation_performance'}
# true_set = {'backlit keyboard, pain, negative, keyboard design_features'}
# predicted_set = {'NULL, disappointed, negative, laptop operation_performance', 'NULL, slow, negative, laptop operation_performance'}
# true_set = {'NULL, disappointed, negative, laptop operation_performance', 'NULL, slow, negative, laptop operation_performance'}
# predicted_set = {'mouse pad, slow, negative, keyboard operation_performance', 'keyboard, fine, positive, keyboard general'}
# true_set = {'mouse pad, fine, positive, keyboard design_features', 'keyboard, fine, positive, keyboard design_features', 'NULL, slow, negative, laptop general'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, negative, laptop general'}
# predicted_set = {'keypad, worse, negative, keyboard general', 'keypad, crazy, negative, keyboard general'}
# true_set = {'keypad, worse, negative, keyboard general', 'keypad, crazy, negative, keyboard general'}
# predicted_set = {'laptop, solid, positive, laptop design_features'}
# true_set = {'laptop, solid, positive, laptop general'}
# predicted_set = {'product, NULL, negative, laptop general'}
# true_set = {'product, NULL, negative, laptop quality'}
# predicted_set = {'laptop, NULL, negative, laptop general'}
# true_set = {'laptop, NULL, neutral, laptop general'}
# predicted_set = {'hybrid storage units, NULL, negative, hard_disc general', 'caps lock, NULL, negative, keyboard design_features', 'keyboard, NULL, negative, keyboard design_features', 'web cam, sucks, negative, display operation_performance'}
# true_set = {'hybrid storage units, like, positive, memory general', 'web cam, poor, negative, hardware operation_performance', 'keyboard, NULL, negative, keyboard design_features', 'web cam, sucks, negative, hardware operation_performance', 'processor, like, positive, cpu operation_performance', 'caps lock, NULL, negative, keyboard design_features', 'num lock, NULL, negative, keyboard design_features'}
# predicted_set = {'NULL, lightweight, positive, laptop design_features'}
# true_set = {'NULL, lightweight, positive, laptop design_features'}
# predicted_set = {'backlight, NULL, negative, keyboard operation_performance'}
# true_set = {'backlight, NULL, negative, keyboard operation_performance'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop general'}
# predicted_set = {'warranty stuff, NULL, negative, warranty general'}
# true_set = {'warranty stuff, NULL, neutral, warranty general'}
# predicted_set = {'ram, available, neutral, memory general'}
# true_set = {'ram, available, positive, hardware general'}
# predicted_set = {'hard drive upgrade, available, positive, hard_disc general'}
# true_set = {'hard drive, available, positive, memory operation_performance'}
# predicted_set = {'touchpad, NULL, negative, hardware operation_performance'}
# true_set = {'touchpad, NULL, negative, hardware operation_performance'}
# predicted_set = {'computer, functional, neutral, laptop operation_performance', 'computer, not the greatest, neutral, laptop operation_performance'}
# true_set = {'computer, not the greatest, neutral, laptop general', 'computer, functional, neutral, laptop general'}
# predicted_set = {'computer, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, negative, laptop general', 'computer, NULL, neutral, laptop general'}
# predicted_set = {'asus warranty, NULL, negative, warranty general'}
# true_set = {'asus warranty, NULL, negative, support general'}
# predicted_set = {'display, NULL, negative, display operation_performance'}
# true_set = {'display, NULL, negative, display general'}
# predicted_set = {'asus customer support, NULL, negative, support general'}
# true_set = {'asus customer support, NULL, negative, support operation_performance'}
# predicted_set = {'NULL, bad, negative, laptop general'}
# true_set = {'NULL, bad, negative, laptop quality'}
# predicted_set = {'asus laptop, NULL, negative, laptop design_features', 'touchpad, non - functioning, negative, keyboard operation_performance'}
# true_set = {'touchpad, non - functioning, negative, hardware quality', 'asus laptop, NULL, negative, laptop general'}
# predicted_set = {'screen, broke, negative, display operation_performance'}
# true_set = {'screen, NULL, negative, display general'}
# predicted_set = {'customer support, NULL, negative, support general'}
# true_set = {'customer support, no good, negative, support general'}
# predicted_set = {'keyboard, NULL, negative, keyboard design_features'}
# true_set = {'keyboard, NULL, negative, keyboard design_features'}
# predicted_set = {'item, light, positive, laptop portability', 'item, big, positive, laptop portability'}
# true_set = {'NULL, big, positive, display design_features', 'item, light, positive, laptop portability', 'NULL, ease, positive, display design_features'}
# predicted_set = {'machine, good, positive, laptop general'}
# true_set = {'work machine, good, positive, laptop general'}
# predicted_set = {'computer, NULL, negative, laptop operation_performance'}
# true_set = {'computer, NULL, negative, laptop operation_performance'}
# predicted_set = {'boots up, NULL, positive, laptop operation_performance', 'shuts down, NULL, negative, laptop operation_performance'}
# true_set = {'shuts down, NULL, positive, laptop operation_performance', 'boots up, NULL, positive, laptop operation_performance'}
# predicted_set = {'keyboard, like, positive, keyboard design_features'}
# true_set = {'keyboard, like, positive, keyboard design_features'}
# predicted_set = {'NULL, well, positive, laptop general'}
# true_set = {'NULL, well, positive, laptop general'}
# predicted_set = {'NULL, NULL, positive, laptop operation_performance', 'NULL, NULL, positive, laptop design_features'}
# true_set = {'NULL, NULL, positive, laptop operation_performance', 'NULL, NULL, negative, laptop design_features'}
# predicted_set = {'ports, decent, positive, ports general'}
# true_set = {'ports, decent, positive, ports quality', 'ports, available, positive, ports quality'}
# predicted_set = {'dvd drive, NULL, neutral, multimedia_devices general'}
# true_set = {'dvd drive, NULL, neutral, optical_drives general'}
# predicted_set = {'NULL, hot, negative, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, laptop quality'}
# predicted_set = {'grid benchmark, high, positive, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, laptop quality'}
# predicted_set = {'i5 mobile processor, NULL, neutral, cpu general'}
# true_set = {'i5 mobile processor, NULL, neutral, cpu general'}
# predicted_set = {'ddr4 ram, upgradable, positive, memory design_features'}
# true_set = {'ddr4 ram, upgradable, positive, memory general'}
# predicted_set = {'battery life, decent, positive, battery general'}
# true_set = {'battery life, decent, positive, battery operation_performance'}
# predicted_set = {'unit, impressed, positive, laptop general'}
# true_set = {'unit, pleasantly, positive, laptop general'}
# predicted_set = {'laptop, best, positive, laptop general'}
# true_set = {'laptop, best, positive, laptop general'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, positive, laptop operation_performance'}
# predicted_set = {'keyboard backlight, annoying, negative, keyboard operation_performance'}
# true_set = {'keyboard backlight, annoying, negative, keyboard operation_performance'}
# predicted_set = {'ram, upgradeable, positive, memory design_features'}
# true_set = {'ram, upgradeable, positive, memory usability'}
# predicted_set = {'touchpad, love, positive, keyboard design_features'}
# true_set = {'keyboard, love, positive, keyboard design_features', 'touchpad, love, positive, keyboard design_features'}
# predicted_set = {'NULL, good, positive, laptop general', 'NULL, fast, positive, laptop operation_performance'}
# true_set = {'NULL, trouble - free, positive, laptop operation_performance', 'NULL, not fancy, neutral, laptop design_features', 'NULL, good, positive, laptop operation_performance', 'NULL, fast, positive, laptop operation_performance'}
# predicted_set = {'feature, useful, positive, software general'}
# true_set = {'feature, useful, positive, keyboard design_features'}
# predicted_set = {'ram, NULL, positive, memory general', 'storage, NULL, positive, memory general'}
# true_set = {'ram, NULL, positive, memory usability'}
# predicted_set = {'mx150, enough, positive, laptop general'}
# true_set = {'mx150, NULL, neutral, graphics design_features'}
# predicted_set = {'solid state drive, love, positive, hard_disc operation_performance'}
# true_set = {'solid state drive, love, positive, hard_disc general'}
# predicted_set = {'laptop, NULL, neutral, laptop general'}
# true_set = {'laptop, NULL, positive, laptop general'}
# predicted_set = {'boots up, fast, positive, laptop operation_performance'}
# true_set = {'boots up, fast, positive, laptop operation_performance'}
# predicted_set = {'system, impressed, positive, os general'}
# true_set = {'system, impressed, positive, os operation_performance'}
# predicted_set = {'mastercam, good, positive, multimedia_devices operation_performance'}
# true_set = {'mastercam, good, positive, multimedia_devices operation_performance'}
# predicted_set = {'amazon, great, positive, support general'}
# true_set = {'amazon, great, positive, support quality'}
# predicted_set = {'screen, not great, neutral, display general', 'screen, decent, positive, display general'}
# true_set = {'screen, not great, positive, display design_features', 'screen, decent, positive, display design_features'}
# predicted_set = {'back lit keyboard, like, positive, keyboard general'}
# true_set = {'back lit keyboard, like, positive, keyboard design_features'}
# predicted_set = {'NULL, good, positive, laptop general', 'NULL, cheap, positive, laptop price'}
# true_set = {'NULL, cheap, positive, laptop price', 'NULL, good, positive, laptop price'}
# predicted_set = {'screen, perfectly, positive, display general', 'screen, adequate, positive, display general'}
# true_set = {'screen, perfectly, positive, display operation_performance'}
# predicted_set = {'boots up, sleek, positive, laptop design_features', 'boots up, quick, positive, laptop operation_performance', 'boots up, beautiful, positive, laptop design_features'}
# true_set = {'NULL, sleek, positive, laptop design_features', 'boots up, quick, positive, laptop operation_performance', 'NULL, beautiful, positive, laptop design_features'}
# predicted_set = {'chromebooks, great, positive, laptop general', 'google, great, positive, company general'}
# true_set = {'google and partners, great, positive, company general'}
# predicted_set = {'tablet, easy, positive, laptop usability', 'tablet, affordable, positive, laptop price', 'tablet, recommend, positive, laptop general'}
# true_set = {'NULL, affordable, positive, laptop price', 'NULL, easy, positive, laptop usability'}
# predicted_set = {'touch pad, NULL, neutral, keyboard usability'}
# true_set = {'touch pad, NULL, positive, keyboard usability'}
# predicted_set = {'NULL, fantastic, positive, laptop general'}
# true_set = {'NULL, fantastic, positive, laptop general'}
# predicted_set = {'samsung chromebook, inexpensive, positive, laptop price'}
# true_set = {'samsung chromebook, inexpensive, positive, laptop price'}
# predicted_set = {"product, ' t be happier, positive, laptop general"}
# true_set = {"product, ' t be happier, positive, laptop general"}
# predicted_set = {'screen hinge, strong, positive, display quality'}
# true_set = {'screen hinge, strong, positive, display quality'}
# predicted_set = {'NULL, perfect, positive, laptop design_features', 'NULL, easy, positive, laptop portability'}
# true_set = {'size, perfect, positive, laptop design_features', 'NULL, perfect, positive, laptop portability'}
# predicted_set = {'NULL, great, positive, laptop operation_performance'}
# true_set = {'NULL, great, positive, laptop operation_performance'}
# predicted_set = {'battery life, good, positive, battery general'}
# true_set = {'battery life, good, positive, battery operation_performance'}
# predicted_set = {'chromebook, NULL, positive, laptop connectivity'}
# true_set = {'chromebook, NULL, positive, laptop connectivity'}
# predicted_set = {'android tablets, NULL, negative, laptop operation_performance'}
# true_set = {'android tablets, NULL, negative, laptop connectivity'}
# predicted_set = {'NULL, perfect, positive, laptop general'}
# true_set = {'NULL, perfect, positive, laptop general'}
# predicted_set = {'powers up, immediately, positive, laptop operation_performance', 'keyboard, amazing, positive, keyboard operation_performance', 'battery life, NULL, positive, battery operation_performance'}
# true_set = {'NULL, amazing, positive, laptop design_features', 'keyboard, NULL, positive, keyboard general', 'powers up, NULL, positive, laptop operation_performance', 'battery life, great, positive, battery general'}
# predicted_set = {'product, happier, positive, laptop general'}
# true_set = {'NULL, happier, positive, laptop general'}
# predicted_set = {'samsung chromebook, NULL, neutral, laptop general'}
# true_set = {'brand, NULL, positive, company general', 'samsung chromebook, NULL, positive, laptop general'}
# predicted_set = {'NULL, NULL, neutral, laptop operation_performance'}
# true_set = {'tablet, NULL, positive, laptop operation_performance'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop usability'}
# predicted_set = {'book, good, positive, laptop price', 'book, great, positive, laptop price'}
# true_set = {'book, good, positive, laptop general', 'book, great, positive, laptop price'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'laptop, straight forward, positive, laptop general'}
# true_set = {'laptop, NULL, positive, laptop general'}
# predicted_set = {'NULL, great, positive, laptop general'}
# true_set = {'NULL, great, positive, laptop general'}
# predicted_set = {'os, secure, positive, os design_features'}
# true_set = {'os, secure, positive, os operation_performance'}
# predicted_set = {'product, awesome, positive, laptop general'}
# true_set = {'product, awesome, positive, laptop general'}
# predicted_set = {'tablet, great, positive, laptop general', 'laptop, great, positive, laptop general'}
# true_set = {'tablet, great, positive, laptop general', 'laptop, great, positive, laptop general'}
# predicted_set = {'chormebook, NULL, positive, laptop operation_performance'}
# true_set = {'chormebook, NULL, positive, laptop operation_performance'}
# predicted_set = {'NULL, like, positive, laptop design_features'}
# true_set = {'NULL, like, positive, laptop design_features'}
# predicted_set = {'notebook, decently, positive, laptop design_features', 'notebook, cheap, positive, laptop price', 'notebook, light, positive, laptop design_features'}
# true_set = {'notebook, decently, positive, laptop design_features', 'notebook, cheap, positive, laptop price', 'notebook, light, positive, laptop design_features'}
# predicted_set = {'keyboard, love, positive, keyboard general'}
# true_set = {'keyboard, love, positive, keyboard general'}
# predicted_set = {'chromebook, lightweight, positive, laptop design_features', 'chromebook, easy, positive, laptop portability', 'chromebook, love, positive, laptop general'}
# true_set = {'chromebook, lightweight, positive, laptop design_features', 'chromebook, easy, positive, laptop design_features', 'chromebook, love, positive, laptop general'}
# predicted_set = {'NULL, glad, positive, laptop general'}
# true_set = {'NULL, glad, positive, laptop general'}
# predicted_set = {'navigation, easy, positive, software usability'}
# true_set = {'navigation, easy, positive, software usability'}
# predicted_set = {'NULL, great, positive, laptop usability'}
# true_set = {'NULL, great, positive, laptop operation_performance'}
# predicted_set = {'NULL, well, positive, laptop operation_performance'}
# true_set = {'NULL, well, positive, laptop operation_performance'}
# predicted_set = {'tank blitz, great, positive, software operation_performance', 'roblocks, great, positive, software operation_performance'}
# true_set = {'NULL, great, positive, laptop operation_performance'}
# predicted_set = {"speaker, ' t loud, negative, multimedia_devices operation_performance"}
# true_set = {'speaker, NULL, negative, multimedia_devices operation_performance'}
# predicted_set = {'NULL, love, positive, laptop general'}
# true_set = {'NULL, love, positive, laptop general'}
# predicted_set = {'battery life, great, positive, battery general'}
# true_set = {'battery life, great, positive, battery operation_performance'}
# predicted_set = {'NULL, easy, positive, laptop portability'}
# true_set = {'NULL, easy, positive, laptop portability'}
# predicted_set = {'NULL, recommend, positive, laptop general'}
# true_set = {'NULL, recommend, positive, laptop general'}
# predicted_set = {'NULL, perfect, positive, laptop general'}
# true_set = {'NULL, perfect, positive, laptop general'}
# predicted_set = {'display, NULL, positive, display general', 'speed, NULL, positive, laptop operation_performance', 'samsung, NULL, positive, laptop general', 'battery life, NULL, positive, battery operation_performance'}
# true_set = {'display, NULL, positive, display general', 'samsung, NULL, positive, laptop operation_performance', 'battery life, NULL, positive, battery general', 'software, NULL, positive, software general'}
# predicted_set = {'display, crisp, positive, display operation_performance', 'display, bright, positive, display operation_performance', 'display, cheap, positive, display operation_performance', 'display, forever, positive, display operation_performance'}
# true_set = {'setup, fast, positive, os operation_performance', 'display, bright, positive, display quality', 'setup, cheap, positive, os operation_performance', 'display, crisp, positive, display quality', 'NULL, NULL, positive, power_supply operation_performance'}
# predicted_set = {'NULL, nice, positive, laptop general'}
# true_set = {'NULL, nice, positive, laptop general'}
# predicted_set = {'chromebook, love, positive, laptop general'}
# true_set = {'chromebook, love, positive, laptop general'}
# predicted_set = {'keyboard, small, negative, keyboard design_features', 'keyboard, tight, negative, keyboard design_features'}
# true_set = {'keyboard, small, negative, keyboard design_features', 'keyboard, tight, negative, keyboard design_features'}
# predicted_set = {'laptop, NULL, positive, laptop quality'}
# true_set = {'laptop, high, positive, laptop quality'}
# predicted_set = {'usps, suck, negative, ports operation_performance', 'delivery, off, negative, shipping operation_performance'}
# true_set = {'usps, suck, negative, shipping general', 'delivery, off, negative, shipping general'}
# predicted_set = {'amd a12 processor, fast, positive, cpu operation_performance'}
# true_set = {'amd a12 processor, fast, positive, cpu operation_performance'}
# predicted_set = {'NULL, light, positive, laptop design_features'}
# true_set = {'NULL, light, positive, laptop design_features'}
# predicted_set = {'computer, NULL, positive, laptop general'}
# true_set = {'computer, NULL, positive, laptop general'}
# predicted_set = {'computer, best, positive, laptop price'}
# true_set = {'computer, best, positive, laptop price'}
# predicted_set = {'computer, great, positive, laptop operation_performance'}
# true_set = {'computer, great, positive, laptop general'}
# predicted_set = {'laptop, excellent, positive, laptop general', 'laptop, reasonable, positive, laptop price'}
# true_set = {'laptop, excellent, positive, laptop general', 'laptop, reasonable, positive, laptop price'}
# predicted_set = {'laptop, NULL, positive, laptop operation_performance'}
# true_set = {'laptop, NULL, positive, laptop general'}
# predicted_set = {'NULL, flawlessly, positive, laptop operation_performance', 'battery life, decent, positive, battery general'}
# true_set = {'NULL, flawlessly, positive, laptop operation_performance', 'battery, decent, positive, battery operation_performance'}
# predicted_set = {'laptop, excelente, positive, laptop general'}
# true_set = {'laptop, excelente, positive, laptop general'}
# predicted_set = {'NULL, great, positive, laptop general'}
# true_set = {'graphics, great, positive, graphics general'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'NULL, NULL, positive, laptop operation_performance'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'NULL, NULL, positive, laptop operation_performance', 'NULL, fast, positive, laptop operation_performance'}
# true_set = {'NULL, NULL, positive, laptop general', 'NULL, fast, positive, laptop operation_performance'}
# predicted_set = {'laptop, love, positive, laptop general'}
# true_set = {'laptop, love, positive, laptop general'}
# predicted_set = {'battery, NULL, positive, battery operation_performance'}
# true_set = {'battery, NULL, negative, battery quality'}
# predicted_set = {'screen, sharp, positive, display design_features', 'battery life, good, positive, battery general'}
# true_set = {'screen, sharp, positive, display design_features', 'NULL, light, positive, laptop design_features', 'battery, good, positive, battery general'}
# predicted_set = {'NULL, content, positive, laptop general'}
# true_set = {'NULL, content, positive, laptop general'}
# predicted_set = {'processor, cool, positive, cpu operation_performance', 'performance, great, positive, laptop operation_performance', 'processor, quiet, positive, cpu operation_performance'}
# true_set = {'processor, quiet, positive, laptop operation_performance', 'processor, cool, positive, cpu general', 'processor, great, positive, laptop operation_performance'}
# predicted_set = {'sims 4, smoothly, positive, laptop operation_performance'}
# true_set = {'graphics, smoothly, positive, display operation_performance'}
# predicted_set = {'laptop, excited, positive, laptop general'}
# true_set = {'laptop, excited, positive, laptop general'}
# predicted_set = {'NULL, well, positive, laptop operation_performance'}
# true_set = {'first person shooters, well, positive, software operation_performance'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'laptop, easy, positive, laptop operation_performance'}
# true_set = {'laptop, easy, positive, laptop usability', 'laptop, NULL, positive, laptop operation_performance'}
# predicted_set = {'numbering pad, NULL, negative, keyboard design_features'}
# true_set = {'keyboard, NULL, negative, keyboard design_features'}
# predicted_set = {'NULL, good, positive, laptop general', 'NULL, happy, positive, laptop general'}
# true_set = {'lappy, good, positive, laptop general', 'lappy, happy, positive, laptop general'}
# predicted_set = {'dvd player, surprised, positive, multimedia_devices general', 'dvd player, nice, positive, multimedia_devices general', 'dvd player, thin, positive, multimedia_devices general'}
# true_set = {'NULL, surprised, positive, laptop design_features', 'NULL, light, positive, laptop design_features', 'NULL, nice, positive, laptop general', 'NULL, thin, positive, laptop design_features'}
# predicted_set = {'battery life, NULL, negative, battery general', 'computer, perfect, positive, laptop general'}
# true_set = {'computer, perfect, positive, laptop general', 'battery life, shorter, negative, battery operation_performance'}
# predicted_set = {'screen backlight, NULL, negative, display operation_performance'}
# true_set = {'screen, NULL, negative, display quality'}
# predicted_set = {'processor, fast, positive, cpu operation_performance'}
# true_set = {'processor, fast, positive, cpu operation_performance'}
# predicted_set = {'laptop, NULL, positive, laptop general'}
# true_set = {'laptop, NULL, positive, laptop general'}
# predicted_set = {'battery, undersized, negative, battery design_features'}
# true_set = {'battery, NULL, negative, battery design_features'}
# predicted_set = {'laptop, excellent, positive, laptop general'}
# true_set = {'laptop, excellent, positive, laptop general'}
# predicted_set = {'dvd player, nice, positive, multimedia_devices general'}
# true_set = {'dvd player, nice, positive, optical_drives general'}
# predicted_set = {'ports, NULL, positive, ports general'}
# true_set = {'ports, NULL, positive, ports general'}
# predicted_set = {'laptop, fast, positive, laptop operation_performance'}
# true_set = {'laptop, fast, positive, laptop operation_performance'}
# predicted_set = {'computer, great, positive, laptop general'}
# true_set = {'computer, great, positive, laptop general'}
# predicted_set = {'laptop, great, positive, laptop general'}
# true_set = {'laptop, great, positive, laptop general'}
# predicted_set = {'NULL, pleased, positive, laptop operation_performance'}
# true_set = {'NULL, pleased, positive, laptop general'}
# predicted_set = {'cpu performance, well, positive, cpu operation_performance'}
# true_set = {'cpu, well, positive, cpu operation_performance'}
# predicted_set = {'NULL, NULL, neutral, laptop general'}
# true_set = {'NULL, NULL, neutral, laptop general'}
# predicted_set = {'NULL, like, positive, laptop general'}
# true_set = {'NULL, like, positive, laptop general'}
# predicted_set = {'NULL, NULL, positive, laptop operation_performance'}
# true_set = {'graphics, NULL, positive, graphics operation_performance'}
# predicted_set = {'webpages, quickly, positive, software operation_performance'}
# true_set = {'NULL, quickly, positive, software operation_performance'}
# predicted_set = {'processor, NULL, neutral, cpu operation_performance'}
# true_set = {'processor, NULL, neutral, cpu operation_performance'}
# predicted_set = {'NULL, perfect, positive, laptop general'}
# true_set = {'NULL, perfect, positive, laptop general'}
# predicted_set = {'computer / laptop, good, positive, laptop general'}
# true_set = {'laptop, good, positive, laptop general', 'computer, good, positive, laptop general'}
# predicted_set = {'NULL, love, positive, laptop design_features', 'NULL, sleek, positive, laptop design_features', 'NULL, thin, positive, laptop design_features'}
# true_set = {'NULL, love, positive, laptop design_features', 'NULL, sleek, positive, laptop design_features', 'NULL, thin, positive, laptop design_features'}
# predicted_set = {'keyboard, great, positive, keyboard operation_performance'}
# true_set = {'keyboard, great, positive, keyboard usability'}
# predicted_set = {'computer, like, positive, laptop general', 'computer, fast, positive, laptop operation_performance'}
# true_set = {'computer, fast, positive, laptop operation_performance'}
# predicted_set = {'laptop, solid, positive, laptop general'}
# true_set = {'laptop, solid, positive, laptop general'}
# predicted_set = {'laptop, NULL, negative, laptop general'}
# true_set = {'laptop, NULL, negative, laptop general'}
# predicted_set = {'battery life, NULL, neutral, battery operation_performance'}
# true_set = {'battery life, NULL, neutral, battery general'}
# predicted_set = {'battery life, short, positive, battery operation_performance'}
# true_set = {'battery life, short, negative, battery operation_performance'}
# predicted_set = {'design, sleek, positive, laptop design_features'}
# true_set = {'design, sleek, positive, laptop design_features'}
# predicted_set = {'NULL, easy, positive, laptop usability'}
# true_set = {'NULL, easy, positive, laptop usability'}
# predicted_set = {'computer, nice, positive, laptop general'}
# true_set = {'computer, nice, positive, laptop general'}
# predicted_set = {'laptop, designed, positive, laptop design_features', 'laptop, well engineered, positive, laptop design_features'}
# true_set = {'laptop, well, positive, laptop design_features'}
# predicted_set = {'laptop, nice, positive, laptop general'}
# true_set = {'laptop, nice, positive, laptop general'}
# predicted_set = {'NULL, perfect, positive, laptop general'}
# true_set = {'NULL, perfect, positive, laptop general'}
# predicted_set = {'NULL, resonable, positive, laptop price'}
# true_set = {'NULL, resonable, positive, laptop price'}
# predicted_set = {'laptop, fast, positive, laptop operation_performance'}
# true_set = {'laptop, fast, positive, laptop operation_performance'}
# predicted_set = {'NULL, great, positive, laptop price', 'battery, terrible, negative, battery general'}
# true_set = {'NULL, NULL, positive, laptop operation_performance', 'NULL, NULL, positive, laptop price', 'battery, terrible, negative, battery general'}
# predicted_set = {'NULL, slow, negative, laptop operation_performance'}
# true_set = {'NULL, slow, negative, laptop operation_performance'}
# predicted_set = {'computer, great, positive, laptop general', 'setup, fast, positive, laptop operation_performance', 'computer, easy, positive, laptop usability'}
# true_set = {'computer, great, positive, laptop general', 'setup, easy, positive, laptop usability', 'setup, fast, positive, laptop usability'}
# predicted_set = {'laptop, nice, positive, laptop design_features', 'laptop, love, positive, laptop general'}
# true_set = {'laptop, nice, positive, laptop design_features'}
# predicted_set = {'graphics, good, positive, graphics general'}
# true_set = {'graphics, good, positive, graphics general'}
# predicted_set = {'warranty, NULL, positive, warranty general'}
# true_set = {'warranty, NULL, negative, warranty general'}
# predicted_set = {'touch screen, NULL, negative, display operation_performance'}
# true_set = {'touch screen, NULL, negative, display quality'}
# predicted_set = {'chromebook, great, positive, laptop general', 'chromebook, unusable, negative, laptop operation_performance'}
# true_set = {'chromebook, great, positive, laptop general', 'phantom touches, NULL, negative, keyboard general'}
# predicted_set = {'pixel, NULL, negative, display operation_performance'}
# true_set = {'pixel, NULL, negative, display operation_performance'}
# predicted_set = {'screen, beautiful, positive, display design_features'}
# true_set = {'screen, beautiful, positive, display design_features'}
# predicted_set = {'chromebooks, prefer, positive, laptop general'}
# true_set = {'NULL, NULL, neutral, display design_features'}
# predicted_set = {'NULL, NULL, negative, laptop operation_performance', 'NULL, solid, positive, laptop operation_performance', 'NULL, fine, positive, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, laptop operation_performance', 'NULL, solid, positive, laptop operation_performance', 'NULL, fine, positive, laptop operation_performance'}
# predicted_set = {'hardware, annoying, negative, hardware general'}
# true_set = {'hardware, annoying, negative, hardware quality'}
# predicted_set = {'NULL, useless, negative, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, os design_features'}
# predicted_set = {'touch screen, wonderfully, positive, display operation_performance'}
# true_set = {'touch screen, wonderfully, positive, display operation_performance'}
# predicted_set = {'backspace key, small, negative, keyboard design_features'}
# true_set = {'backspace key, small, negative, keyboard design_features'}
# predicted_set = {'screen, not very durable, negative, display quality', 'screen, irk, negative, display quality'}
# true_set = {'screen, not very durable, negative, display quality'}
# predicted_set = {'NULL, NULL, negative, laptop operation_performance'}
# true_set = {'NULL, hard, negative, laptop usability'}
# predicted_set = {'device, bad, negative, laptop price', 'device, expensive, negative, laptop price'}
# true_set = {'device, expensive, negative, laptop price'}
# predicted_set = {'profile, small, positive, laptop design_features', 'screen, gorgeous, positive, display general', 'NULL, awesome, positive, laptop general', 'NULL, lightweight, positive, laptop design_features'}
# true_set = {'profile, small, positive, laptop design_features', 'screen, gorgeous, positive, display design_features', 'profile, lightweight, positive, laptop design_features', 'stylus, awesome, positive, hardware design_features'}
# predicted_set = {'NULL, fair, neutral, laptop general'}
# true_set = {'verified purchase, NULL, neutral, support general'}
# predicted_set = {"computer, ' t recommend, negative, laptop general"}
# true_set = {'NULL, recommend, negative, laptop operation_performance'}
# predicted_set = {'NULL, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, negative, laptop general'}
# predicted_set = {'screen, good, positive, display design_features'}
# true_set = {'screen, good, positive, display general'}
# predicted_set = {'apps, terrible, negative, software quality', 'apps, not really enjoyable, negative, software operation_performance'}
# true_set = {'apps, not really enjoyable, negative, software general', 'NULL, terrible, negative, laptop quality'}
# predicted_set = {'battery life, ok, neutral, battery general'}
# true_set = {'battery life, ok, neutral, battery general'}
# predicted_set = {'NULL, easy, negative, laptop operation_performance'}
# true_set = {'NULL, NULL, negative, keyboard general'}
# predicted_set = {'android app support, NULL, negative, support general'}
# true_set = {'android app support, NULL, negative, software quality'}
# predicted_set = {'android app, disappointed, negative, software general'}
# true_set = {'android app, disappointed, negative, software design_features'}
# predicted_set = {'battery life, mediocre, negative, battery general'}
# true_set = {'battery life, mediocre, neutral, battery general'}
# predicted_set = {'amazon, NULL, neutral, support general'}
# true_set = {'amazon, NULL, neutral, support general'}
# predicted_set = {'display, great, positive, display general', 'keyboard, great, positive, keyboard general', 'battery, good, positive, battery general'}
# true_set = {'display, great, positive, display general', 'keyboard, great, positive, keyboard general', 'battery, good, positive, battery general'}
# predicted_set = {'tablet, NULL, neutral, laptop general'}
# true_set = {'tablet, NULL, negative, laptop general'}
# predicted_set = {'chromeos + samsung, bad, negative, os general'}
# true_set = {'samsung, NULL, negative, company general', 'chromeos, NULL, negative, laptop general'}
# predicted_set = {'computer, NULL, negative, laptop operation_performance', 'computer, nice, positive, laptop general'}
# true_set = {'computer, NULL, negative, laptop design_features'}
# predicted_set = {'keyboard, inconvenient, negative, keyboard design_features'}
# true_set = {'keyboard, inconvenient, negative, keyboard usability'}
# predicted_set = {'chromebook, impressive, positive, laptop price'}
# true_set = {'chromebook, impressive, positive, laptop price'}
# predicted_set = {'NULL, great, positive, laptop price'}
# true_set = {'NULL, great, positive, laptop price'}
# predicted_set = {'computer, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, positive, laptop price'}
# predicted_set = {'acer, bad, negative, laptop general'}
# true_set = {'acer, NULL, positive, company general'}
# predicted_set = {'trackpad, pleasure, positive, keyboard general', 'trackpad, responsive, positive, keyboard general', 'trackpad, nice, positive, keyboard general'}
# true_set = {'trackpad, pleasure, positive, keyboard operation_performance', 'trackpad, responsive, positive, keyboard operation_performance', 'trackpad, nice, positive, keyboard design_features', 'trackpad, oversize, positive, keyboard design_features'}
# predicted_set = {'computer, NULL, positive, laptop operation_performance', 'battery life, NULL, positive, battery operation_performance'}
# true_set = {'battery life, NULL, positive, battery operation_performance'}
# predicted_set = {'aluminum shell, attractive, positive, laptop design_features', 'keyboard, better, positive, keyboard general', 'unit, nice, positive, laptop design_features'}
# true_set = {'aluminum shell, attractive, positive, laptop design_features', 'keyboard, decent, positive, laptop design_features', 'keyboard, better, positive, laptop design_features', 'aluminum shell, nice, positive, laptop design_features'}
# predicted_set = {'card reader / writer, NULL, negative, ports general'}
# true_set = {'card reader / writer, NULL, negative, ports general'}
# predicted_set = {'NULL, love, positive, laptop general'}
# true_set = {'NULL, love, positive, laptop general'}
# predicted_set = {'laptop, good, positive, laptop general'}
# true_set = {'it, good, positive, laptop operation_performance'}
# predicted_set = {'battery life, incredible, positive, battery operation_performance'}
# true_set = {'battery life, incredible, positive, battery operation_performance'}
# predicted_set = {'NULL, well, positive, laptop operation_performance'}
# true_set = {'NULL, well, positive, laptop operation_performance'}
# predicted_set = {'NULL, great, positive, laptop price', 'chromebook, NULL, negative, laptop operation_performance'}
# true_set = {'NULL, great, positive, laptop price'}
# predicted_set = {'chrome os, NULL, negative, os general'}
# true_set = {'chrome os, NULL, negative, os general'}
# predicted_set = {'play store, NULL, negative, software general'}
# true_set = {'devise, NULL, negative, laptop usability'}
# predicted_set = {'replacement, powerful, positive, laptop operation_performance', 'replacement, cheaper, positive, laptop price', 'chromebook, NULL, neutral, laptop general'}
# true_set = {'chromebook, NULL, negative, laptop general'}
# predicted_set = {'hdmi and usb ports, misery, negative, ports design_features', 'back, NULL, negative, ports design_features'}
# true_set = {'hdmi and usb ports, misery, negative, ports design_features'}
# predicted_set = {'chromebook, superb, positive, laptop general'}
# true_set = {'chromebook, superb, positive, laptop general'}
# predicted_set = {'quad - core celeron n3160, respectable, positive, cpu general'}
# true_set = {'quad - core celeron n3160, respectable, positive, cpu operation_performance'}
# predicted_set = {'design, solid, positive, laptop design_features', 'design, well - balanced, positive, laptop design_features'}
# true_set = {'design, solid, positive, laptop design_features', 'design, well - balanced, positive, laptop design_features'}
# predicted_set = {'laptop, favorite, positive, laptop general'}
# true_set = {'laptop, favorite, positive, laptop general'}
# predicted_set = {'chromebook, pleased, positive, laptop operation_performance'}
# true_set = {'chromebook, pleased, positive, laptop operation_performance'}
# predicted_set = {'chromeos, decent, positive, os general'}
# true_set = {'chromeos, decent, positive, os usability'}
# predicted_set = {'machine, hesitant, negative, laptop price', 'machine, amazing, positive, laptop general'}
# true_set = {'NULL, hesitant, neutral, laptop price', 'machine, amazing, positive, laptop general'}
# predicted_set = {'machine, pleasing, positive, laptop design_features'}
# true_set = {'machine, pleasing, positive, laptop design_features'}
# predicted_set = {'model, NULL, positive, laptop general'}
# true_set = {'model, NULL, neutral, laptop general'}
# predicted_set = {'trackpad, delicate, negative, keyboard design_features'}
# true_set = {'trackpad, delicate, negative, keyboard quality'}
# predicted_set = {'battery, good, positive, battery general'}
# true_set = {'battery, good, positive, battery general'}
# predicted_set = {'laptop, ideal, positive, laptop general'}
# true_set = {'laptop, ideal, positive, laptop operation_performance'}
# predicted_set = {'chromebook, NULL, negative, laptop operation_performance'}
# true_set = {'chromebook, NULL, neutral, laptop usability'}
# predicted_set = {'battery, good, positive, battery general'}
# true_set = {'battery, good, positive, battery general'}
# predicted_set = {'celeron processor, slow, negative, cpu operation_performance'}
# true_set = {'celeron processor, slow, negative, cpu operation_performance'}
# predicted_set = {'chromebook, NULL, neutral, laptop general'}
# true_set = {'chromebook, NULL, neutral, laptop general'}
# predicted_set = {'NULL, fast, positive, laptop operation_performance'}
# true_set = {'NULL, fast, positive, laptop operation_performance'}
# predicted_set = {'NULL, NULL, negative, laptop general'}
# true_set = {'NULL, NULL, negative, laptop design_features'}
# predicted_set = {'software, NULL, positive, software operation_performance'}
# true_set = {'graphic, NULL, positive, graphics operation_performance'}
# predicted_set = {'NULL, plus, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop portability'}
# predicted_set = {'drives, NULL, neutral, hard_disc general'}
# true_set = {'solid state drive, NULL, neutral, hard_disc general'}
# predicted_set = {'speakers, NULL, positive, multimedia_devices general'}
# true_set = {'speakers, new, positive, multimedia_devices design_features'}
# predicted_set = {'dvd drive, NULL, negative, multimedia_devices general'}
# true_set = {'dvd drive, NULL, negative, multimedia_devices general'}
# predicted_set = {'NULL, well, positive, laptop operation_performance'}
# true_set = {'NULL, well, neutral, hardware operation_performance'}
# predicted_set = {'laptop, light, positive, laptop design_features'}
# true_set = {'NULL, light, positive, laptop portability'}
# predicted_set = {'screen, sharp, positive, display design_features', 'screen, good, positive, display design_features'}
# true_set = {'screen, sharp, positive, display general', 'screen, good, positive, display general'}
# ...
# true_set = {"keyboard, ' t find it particularly spectacular, neutral, keyboard general", 'keyboard, praised, positive, keyboard general'}
# predicted_set = {'NULL, sturdy, positive, laptop design_features', 'NULL, light, positive, laptop design_features'}
# true_set = {'NULL, sturdy, positive, laptop design_features', 'NULL, light, positive, laptop design_features'}
# predicted_set = {'battery life, NULL, positive, battery general'}
# true_set = {'battery life, NULL, neutral, battery general'}
# predicted_set = {'keyboard, comfortable, positive, keyboard operation_performance'}
# true_set = {'keyboard, comfortable, positive, keyboard usability'}
# predicted_set = {'screen, bright, positive, display design_features', 'screen, clear, positive, display design_features', 'system, NULL, positive, os operation_performance'}
# true_set = {'screen, bright, positive, display design_features', 'screen, clear, positive, display design_features', 'system, NULL, positive, os operation_performance'}
# predicted_set = {'chromebook, NULL, neutral, laptop general'}
# true_set = {'chromebook, NULL, neutral, laptop general'}
# predicted_set = {'battery, long, positive, battery operation_performance'}
# true_set = {'battery, incredibly, positive, battery operation_performance', 'battery, long, positive, battery operation_performance'}
# predicted_set = {'NULL, NULL, positive, laptop connectivity'}
# true_set = {'it, NULL, positive, laptop connectivity'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'computer, NULL, neutral, laptop general'}
# true_set = {'computer, NULL, positive, laptop general'}
# predicted_set = {'asus flip 302, NULL, neutral, laptop general'}
# true_set = {'asus flip 302, NULL, positive, laptop general'}
# predicted_set = {'battery life, good, positive, battery general', 'keyboard experience, great, positive, keyboard general'}
# true_set = {'keyboard, great, positive, keyboard operation_performance', 'battery life, good, positive, battery general'}
# predicted_set = {'plugs, bad, negative, power_supply general', 'plugs, good, positive, power_supply general'}
# true_set = {'plugs, good and bad, neutral, ports general'}
# predicted_set = {'NULL, unenjoyable, negative, laptop operation_performance', 'NULL, low, negative, laptop operation_performance'}
# true_set = {'headphones, unenjoyable, negative, multimedia_devices operation_performance', 'headphones, low, negative, multimedia_devices operation_performance', 'headphones, horribly, negative, multimedia_devices operation_performance'}
# predicted_set = {'keyboard, great, positive, keyboard operation_performance', 'keyboard, nice, positive, keyboard design_features'}
# true_set = {'keyboard, nice, positive, keyboard design_features', 'tablet, great, positive, laptop design_features'}
# predicted_set = {'machine, better, positive, laptop general'}
# true_set = {'machine, better, positive, laptop general'}
# predicted_set = {'NULL, nice, positive, laptop design_features', 'NULL, perfect, positive, laptop design_features', 'NULL, bright, positive, laptop design_features'}
# true_set = {'size, perfect, positive, laptop design_features', 'size, nice, positive, laptop design_features', 'size, bright, positive, laptop design_features'}
# predicted_set = {'laptop, NULL, negative, laptop price'}
# true_set = {"laptop, ' t think you ' ll find a better, positive, laptop price"}
# predicted_set = {'NULL, thin, positive, laptop design_features', 'NULL, light, positive, laptop design_features'}
# true_set = {'NULL, light, positive, laptop design_features', 'NULL, thin, positive, laptop design_features'}
# predicted_set = {'NULL, NULL, positive, laptop design_features'}
# true_set = {'NULL, NULL, positive, laptop portability'}
# predicted_set = {'NULL, strong, positive, laptop quality', 'NULL, durable, positive, laptop quality'}
# true_set = {'NULL, strong, positive, laptop operation_performance', 'NULL, light, positive, laptop design_features', 'NULL, durable, positive, laptop operation_performance'}
# predicted_set = {'picture quality, good, positive, display quality', 'book, responsive, positive, laptop operation_performance', 'book, fast, positive, laptop operation_performance'}
# true_set = {'picture quality, good, positive, display quality', 'book, responsive, positive, laptop operation_performance', 'book, fast, positive, laptop operation_performance'}
# predicted_set = {"asus c302, ' t recommend, negative, laptop general"}
# true_set = {'asus c302, NULL, positive, laptop general'}
# predicted_set = {'keyboard, weak, negative, keyboard design_features'}
# true_set = {'keyboard, weak, negative, keyboard design_features'}
# predicted_set = {'touchscreen, well, positive, display operation_performance'}
# true_set = {'touchscreen, well, positive, display operation_performance'}
# predicted_set = {'NULL, handy, positive, laptop usability'}
# true_set = {'NULL, handy, positive, laptop operation_performance'}
# predicted_set = {'NULL, light, positive, laptop design_features', 'NULL, comfortable, positive, laptop usability'}
# true_set = {'NULL, light, positive, laptop design_features', 'NULL, comfortable, positive, laptop usability'}
# predicted_set = {'sound, low, negative, multimedia_devices operation_performance'}
# true_set = {'aux speaker / headphone, low, negative, multimedia_devices operation_performance', 'sound, low, negative, multimedia_devices operation_performance'}
# predicted_set = {'spacebar, NULL, negative, keyboard operation_performance'}
# true_set = {'spacebar, NULL, negative, keyboard operation_performance'}
# predicted_set = {'computer, favorite, positive, laptop general'}
# true_set = {'computer, favorite, positive, laptop general'}
# predicted_set = {'battery life, stunning, positive, battery general'}
# true_set = {'battery life, stunning, positive, battery general'}
# predicted_set = {'NULL, satisfied, positive, laptop general'}
# true_set = {'purchase, satisfied, positive, laptop general'}
# predicted_set = {'computers, best, positive, laptop general'}
# true_set = {'chromebook, best, positive, laptop general', 'computers, best, positive, laptop general'}
# predicted_set = {'asus chromebook flip 302ca, fast, positive, laptop operation_performance', 'asus chromebook flip 302ca, smooth, positive, laptop operation_performance', 'asus chromebook flip 302ca, well engineered, positive, laptop design_features', 'asus chromebook flip 302ca, incredibly, positive, laptop design_feature', 'asus chromebook flip 302ca, incredibly, positive, laptop design_features'}
# true_set = {'asus chromebook flip 302ca, well, positive, laptop design_features', 'asus chromebook flip 302ca, smooth, positive, laptop operation_performance', 'asus chromebook flip 302ca, fast, positive, laptop operation_performance', 'asus chromebook flip 302ca, incredibly, positive, laptop design_features'}
# predicted_set = {'screen resolution, great, positive, display operation_performance'}
# true_set = {'screen resolution, great, positive, display general'}
# predicted_set = {'touch pad, accurate, positive, keyboard operation_performance'}
# true_set = {'touch pad, accurate, positive, hardware operation_performance'}
# predicted_set = {'screen, gripe, negative, display design_features', 'keyboard, gripe, negative, keyboard design_features'}
# true_set = {'keyboard backlight, NULL, negative, keyboard design_features', 'screen brightness, NULL, negative, display design_features'}
# predicted_set = {'chromebook, worth, positive, laptop price', 'chromebook, pleased, positive, laptop general'}
# true_set = {'purchase, pleased, positive, laptop general', 'chromebook, worth, positive, laptop price'}
# predicted_set = {'touchscreen, nice, positive, keyboard usability'}
# true_set = {'touchscreen, nice, positive, display usability'}
# predicted_set = {'screen, sharp, positive, display operation_performance', 'keyboard, comfortable, positive, keyboard operation_performance'}
# true_set = {'keyboard, comfortable, positive, keyboard usability', 'screen, sharp, positive, display design_features'}
# predicted_set = {'NULL, portable, positive, laptop portability', 'battery, NULL, positive, battery operation_performance'}
# true_set = {'NULL, portable, positive, laptop portability', 'battery, NULL, positive, battery operation_performance'}
# predicted_set = {'chromebook, love, positive, laptop general'}
# true_set = {'chromebook, love, positive, laptop general'}
# predicted_set = {'360 flip feature, easy, positive, keyboard usability', 'touch screen, accurate, positive, display operation_performance'}
# true_set = {'360 flip, easy, positive, out_of_scope design_features'}
# predicted_set = {'chromebook, pros, positive, laptop general', 'chromebook, outweighs, positive, laptop general'}
# true_set = {'chromebook, NULL, positive, laptop general'}
# predicted_set = {'computer, great, positive, laptop price'}
# true_set = {'computer, great, positive, laptop general', 'computer, great, positive, laptop price'}
# predicted_set = {'usb - c, NULL, neutral, ports design_features'}
# true_set = {'usb - c, NULL, positive, ports general'}
# predicted_set = {'chromebook, expensive, negative, laptop price'}
# true_set = {'chromebook, expensive, negative, laptop price'}
# predicted_set = {'NULL, perfect, positive, laptop usability'}
# true_set = {'NULL, perfect, positive, laptop general'}
# predicted_set = {'laptop, happy, positive, laptop general', 'laptop, love, positive, laptop general'}
# true_set = {'laptop, love, positive, laptop general', 'laptop, happy, positive, laptop price'}
# predicted_set = {'laptop, solid, positive, laptop operation_performance'}
# true_set = {'laptop, solid, positive, laptop operation_performance'}
# predicted_set = {'wifi connectivity, strong, positive, ports connectivity', 'wifi connectivity, consistent, positive, ports connectivity'}
# true_set = {'wifi connectivity, consistent, positive, ports operation_performance', 'wifi connectivity, strong, positive, ports operation_performance'}
# predicted_set = {"speakers, ' t like, negative, multimedia_devices operation_performance", "screen, ' t bright enough, negative, display design_features"}
# true_set = {"screen, ' t bright, negative, display operation_performance", "screen, ' t like, negative, display operation_performance", "speakers, ' t louder, negative, multimedia_devices operation_performance"}
# predicted_set = {'c302ca - dh54, NULL, positive, laptop design_features'}
# true_set = {'c302ca - dh54, NULL, positive, laptop operation_performance'}
# predicted_set = {'graphics, great, positive, graphics general'}
# true_set = {'graphics, great, positive, graphics general'}
# predicted_set = {'NULL, NULL, positive, laptop operation_performance'}
# true_set = {'NULL, NULL, positive, laptop operation_performance'}
# predicted_set = {'chromebook, worth, positive, laptop general', 'chromebook, pricey, positive, laptop price'}
# true_set = {'NULL, pricey, negative, laptop price', 'NULL, worth, positive, laptop general'}
# predicted_set = {'NULL, drawback, negative, laptop operation_performance'}
# true_set = {'microsoft office, drawback, negative, software operation_performance'}
# predicted_set = {'NULL, NULL, positive, laptop general'}
# true_set = {'NULL, NULL, positive, laptop general'}
# predicted_set = {'product, ideal, positive, laptop general', 'product, well built, positive, laptop design_features'}
# true_set = {'product, small, positive, laptop design_features', 'product, ideal, positive, laptop design_features', 'product, well built, positive, laptop design_features'}
# predicted_set = {'screen resolution, good, positive, display operation_performance'}
# true_set = {'screen resolution, good, positive, display operation_performance'}
# predicted_set = {'NULL, recommend, positive, laptop general'}
# true_set = {'NULL, recommend, positive, laptop general'}
# predicted_set = {'backlight, love, positive, display operation_performance'}
# true_set = {'backlight, love, positive, keyboard design_features'}
# predicted_set = {"speaker ' s, like, positive, multimedia_devices design_features", "speaker ' s, ok, neutral, multimedia_devices general", "speaker ' s, not amazing, positive, multimedia_devices general"}
# true_set = {'speaker, NULL, positive, multimedia_devices operation_performance', 'speaker, well, positive, multimedia_devices operation_performance'}
# predicted_set = {'play store apps, plus, positive, software usability', 'google docs, comfortable, positive, software usability'}
# true_set = {'google docs, comfortable, positive, software usability'}
# predicted_set = {'keyboard, better, positive, keyboard general', 'screen, good, positive, display general'}
# true_set = {'form factor, better, positive, laptop design_features', 'keyboard, better, positive, keyboard general', 'screen, good, positive, display general'}
# predicted_set = {'tablet mode, like, positive, laptop design_features', 'device, enjoy, positive, laptop design_features'}
# true_set = {'tablet mode, like, positive, laptop general'}
# predicted_set = {'touch screen, good, positive, display general', 'computer, not bad, positive, laptop general'}
# true_set = {'touch screen, good, positive, display general', '360 rotation, good, positive, hardware design_features', 'computer, not bad, neutral, laptop general'}
# predicted_set = {'battery life, amazing, positive, battery general'}
# true_set = {'battery life, amazing, positive, battery operation_performance'}
# predicted_set = {'NULL, good, positive, laptop general'}
# true_set = {'NULL, good, positive, laptop general'}
# predicted_set = {'laptop form, mediocre, negative, laptop general'}
# true_set = {'laptop form, mediocre, neutral, laptop general'}
# predicted_set = {'chromebook, best, positive, laptop general', 'laptops, best, positive, laptop general'}
# true_set = {'laptops, NULL, positive, laptop general', 'chromebook, best, positive, laptop general'}
# predicted_set = {'touchscreen / flip feature, love, positive, display general', 'battery life, great, positive, battery general'}
# true_set = {'NULL, love, positive, display general', 'battery life, great, positive, battery general'}
# predicted_set = {'audio quest dragonfly, perfectly, positive, software operation_performance'}
# true_set = {'usb - c ports, perfectly, positive, ports operation_performance'}
# predicted_set = {'keyboard, big, positive, keyboard design_features'}
# true_set = {'keyboard, NULL, positive, keyboard design_features'}
# predicted_set = {'screen resolution, love, positive, display general', 'laptop, love, positive, laptop general', 'keyboard, love, positive, keyboard general'}
# true_set = {'screen resolution, love, positive, display general', 'laptop, love, positive, laptop general', 'keyboard, love, positive, keyboard general'}
# predicted_set = {'battery, perfect, positive, battery operation_performance'}
# true_set = {'battery, perfect, positive, battery operation_performance'}
# predicted_set = {'battery, NULL, positive, battery operation_performance', 'NULL, quick, positive, laptop operation_performance'}
# true_set = {'battery, NULL, positive, battery operation_performance', 'NULL, quick, positive, laptop operation_performance'}
# predicted_set = {'machine, lean, positive, laptop general', 'machine, clean, positive, laptop general', 'machine, mean, positive, laptop general'}
# true_set = {'machine, clean, positive, laptop design_features', 'machine, mean, positive, laptop design_features'}
# predicted_set = {'switch, awesome, positive, keyboard general'}
# true_set = {'switch, awesome, positive, hardware general'}
# predicted_set = {'backlit keyboard, awesome, positive, keyboard operation_performance'}
# true_set = {'backlit keyboard, awesome, positive, keyboard design_features'}
# predicted_set = {'keyboard, confusing, negative, keyboard general'}
# true_set = {'keyboard, confusing, negative, keyboard general'}
# predicted_set = {'screen display, excellent, positive, display general', 'screen display, bright, positive, display general'}
# true_set = {'graphics, excellent, positive, graphics general', 'screen display, bright, positive, display operation_performance'}
# (0.4355716878402904, 0.41522491349480967, 0.4251550044286979)

# %% [markdown]
# # Huấn luyện

# %%
# Hàm huấn luyện
def train_model(model, tokenizer, train_data, validation_data, num_epochs, batch_size, lr):
    no_improve_epochs = 0
    best_f1 = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    dataloader = build_dataloader(train_data, batch_size, tokenizer)
    optimizer = AdamW(model.parameters(), lr=lr)
    for epoch in range(num_epochs):
        torch.cuda.empty_cache()
        # Huấn luyện #########################################################################################################################################
        print(f"Training epoch {epoch + 1}")
        model.train()
        total_loss = 0
        for batch in dataloader:
            outputs = model(input_ids=batch["input_ids"].to(device), attention_mask=batch["attention_mask"].to(device), labels=batch["labels"].to(device))
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            total_loss += loss.item()
            # Lưu dự đoán vào train_data
            if epoch > 0:
                for key, sequence in zip(batch["batch_keys"], torch.argmax(outputs.logits, dim=-1)):
                    eos_position = (sequence == 1).nonzero(as_tuple=True)[0]
                    if len(eos_position) > 0:  # Nếu tìm thấy <EOS>
                        train_data[key]["text_predict"] = tokenizer.decode(sequence[: eos_position[0]], skip_special_tokens=True)
                    else:
                        train_data[key]["text_predict"] = tokenizer.decode(sequence, skip_special_tokens=True) # Không có <EOS>, giữ nguyên
                    
        print(f"Epoch {epoch + 1} finished with loss: {total_loss / len(dataloader):.4f}. Evaluating")
        # Đánh giá #########################################################################################################################################
        model.eval()
        precision, recall, f1 = evaluate_pipeline_batch(model, tokenizer, validation_data, device, batch_size)
        print("precision =", precision,"recall =", recall,"f1 =", f1)
        if(f1 > best_f1):
            no_improve_epochs = 0
            best_f1 = f1
            # Lưu model
            torch.save(model.state_dict(), f"/chain-of-thought-ABSA/results/experiment_7/{epoch + 1}.pt")
            print("New best_f1 =", best_f1)
        else:
            no_improve_epochs = no_improve_epochs + 1
            if no_improve_epochs == 10:
                print("Huấn huyện xong")
                break

# %%
train_data = process_train_data("/chain-of-thought-ABSA/data/acos/laptop16/train.txt")

train_model(
    model = T5ForConditionalGeneration.from_pretrained("t5-base"), 
    tokenizer = T5Tokenizer.from_pretrained("t5-base"), 
    train_data = train_data,
    validation_data = process_validation_data("/chain-of-thought-ABSA/data/acos/laptop16/dev.txt"),
    num_epochs = 1000,
    batch_size = 16, 
    lr = 3e-5,
)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /opt/conda/lib/python3.11/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Training epoch 1
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Epoch 1 finished with loss: 0.8915. Evaluating
# precision = 0.2433734939759036 recall = 0.23006833712984054 f1 = 0.23653395784543327
# New best_f1 = 0.23653395784543327
# Training epoch 2
# Epoch 2 finished with loss: 0.3465. Evaluating
# precision = 0.3588516746411483 recall = 0.3416856492027335 f1 = 0.3500583430571762
# New best_f1 = 0.3500583430571762
# Training epoch 3
# Epoch 3 finished with loss: 0.2219. Evaluating
# precision = 0.4368932038834951 recall = 0.41002277904328016 f1 = 0.4230317273795534
# New best_f1 = 0.4230317273795534
# Training epoch 4
# Epoch 4 finished with loss: 0.1586. Evaluating
# precision = 0.4429223744292237 recall = 0.4419134396355353 f1 = 0.44241733181299886
# New best_f1 = 0.44241733181299886
# Training epoch 5
# Epoch 5 finished with loss: 0.1224. Evaluating
# precision = 0.4377880184331797 recall = 0.4328018223234624 f1 = 0.4352806414662085
# Training epoch 6
# Epoch 6 finished with loss: 0.0980. Evaluating
# precision = 0.4583333333333333 recall = 0.4510250569476082 f1 = 0.45464982778415614
# New best_f1 = 0.45464982778415614
# Training epoch 7
# Epoch 7 finished with loss: 0.0820. Evaluating
# precision = 0.44730679156908665 recall = 0.43507972665148065 f1 = 0.44110854503464203
# Training epoch 8
# Epoch 8 finished with loss: 0.0707. Evaluating
# precision = 0.45227272727272727 recall = 0.4533029612756264 f1 = 0.4527872582480091
# Training epoch 9
# Epoch 9 finished with loss: 0.0616. Evaluating
# precision = 0.47392290249433106 recall = 0.4760820045558087 f1 = 0.47500000000000003
# New best_f1 = 0.47500000000000003
# Training epoch 10
# Epoch 10 finished with loss: 0.0538. Evaluating
# precision = 0.5069767441860465 recall = 0.49658314350797267 f1 = 0.5017261219792866
# New best_f1 = 0.5017261219792866
# Training epoch 11
# Epoch 11 finished with loss: 0.0491. Evaluating
# precision = 0.4681818181818182 recall = 0.46924829157175396 f1 = 0.4687144482366325
# Training epoch 12
# Epoch 12 finished with loss: 0.0437. Evaluating
# precision = 0.4930875576036866 recall = 0.4874715261958998 f1 = 0.4902634593356243
# Training epoch 13
# Epoch 13 finished with loss: 0.0392. Evaluating
# precision = 0.5212264150943396 recall = 0.5034168564920274 f1 = 0.5121668597914253
# New best_f1 = 0.5121668597914253
# Training epoch 14
# Epoch 14 finished with loss: 0.0363. Evaluating
# precision = 0.46386946386946387 recall = 0.4533029612756264 f1 = 0.4585253456221198
# Training epoch 15
# Epoch 15 finished with loss: 0.0323. Evaluating
# precision = 0.477751756440281 recall = 0.4646924829157175 f1 = 0.4711316397228637
# Training epoch 16
# Epoch 16 finished with loss: 0.0296. Evaluating
# precision = 0.4659090909090909 recall = 0.46697038724373574 f1 = 0.46643913538111487
# Training epoch 17
# Epoch 17 finished with loss: 0.0280. Evaluating
# precision = 0.45727482678983833 recall = 0.4510250569476082 f1 = 0.4541284403669725
# Training epoch 18
# Epoch 18 finished with loss: 0.0249. Evaluating
# precision = 0.4666666666666667 recall = 0.4783599088838269 f1 = 0.47244094488188976
# Training epoch 19
# Epoch 19 finished with loss: 0.0223. Evaluating
# precision = 0.4533333333333333 recall = 0.4646924829157175 f1 = 0.4589426321709786
# Training epoch 20
# Epoch 20 finished with loss: 0.0199. Evaluating
# precision = 0.4864864864864865 recall = 0.4920273348519362 f1 = 0.48924122310305773
# Training epoch 21
# Epoch 21 finished with loss: 0.0188. Evaluating
# precision = 0.4988610478359909 recall = 0.4988610478359909 f1 = 0.4988610478359909
# Training epoch 22
# Epoch 22 finished with loss: 0.0178. Evaluating
# precision = 0.4805491990846682 recall = 0.4783599088838269 f1 = 0.4794520547945206
# Training epoch 23
# Epoch 23 finished with loss: 0.0160. Evaluating
# precision = 0.47392290249433106 recall = 0.4760820045558087 f1 = 0.47500000000000003
# Huấn huyện xong
